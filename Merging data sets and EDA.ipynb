# %% [markdown]
# # TopUp Mama assessment

# %% [markdown]
# ## Task 1
# ### Loading the data sets

# %%
'''importing required libraries'''
import pandas as pd
import numpy as np

# %%
'''Kenya Customers'''
k_cust=pd.read_csv("C:/Users/hp/Desktop/TOP UP MAMA ML/Kenya Customers.csv")
k_cust
# Out:
#       Customer ID Last Used Platform  Is Blocked                Created At  \
# 0         3144837                WEB           0  2021-03-15T17:13:19.000Z
# 1         3174590                WEB           0  2021-03-20T14:15:11.000Z
# 2         3181998                WEB           0  2021-03-21T15:36:51.000Z
# 3         3191244                WEB           0  2021-03-23T08:54:00.000Z
# 4         3274222                WEB           0  2021-04-06T13:52:39.000Z
# ...           ...                ...         ...                       ...
# 4172      5188032                WEB           0  2022-02-17T09:03:10.000Z
# 4173      5188161                WEB           0  2022-02-17T09:31:49.000Z
# 4174      5188263                WEB           0  2022-02-17T09:51:36.000Z
# 4175      5188431                WEB           0  2022-02-17T10:34:19.000Z
# 4176      5189011                WEB           0  2022-02-17T13:07:11.000Z
#
# ...

# %%
'''Kenya Deliveries'''
k_deliv=pd.read_csv("C:/Users/hp/Desktop/TOP UP MAMA ML/Kenya Deliveries.csv")
k_deliv
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (20) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#          Task_ID       Order_ID  Relationship     Team_Name Task_Type  \
# 0      368110390  YR-11265216,0  3.681104e+29  Default Team  Delivery
# 1      368110390  YR-11265216,0  3.681104e+29  Default Team  Delivery
# 2      368109621  YR-11265175,0  3.681096e+29  Default Team  Delivery
# 3      368105817  YR-11265015,0  3.681058e+29  Default Team  Delivery
# 4      368098308  YR-11264651,0  3.680983e+29  Default Team  Delivery
# ...          ...            ...           ...           ...       ...
# 44978  219271375   YR-5319666,0  2.192714e+29  Default Team  Delivery
# 44979  218658360   YR-5304830,0  2.186584e+29  Default Team  Delivery
# 44980  218649867   YR-5304690,0  2.186499e+29  Default Team  Delivery
# ...

# %%
k_deliv.iloc[0:10,20]
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# Name: Tags, dtype: object

# %%
'''Kenya Orders'''
k_orders=pd.read_csv("C:/Users/hp/Desktop/TOP UP MAMA ML/Kenya Orders.csv")
k_orders
# Out:
#        Order ID Order Status       Category Name         SKU  \
# 0      11265015      ORDERED   Cooking Fat & Oil    KKCO0487
# 1      11264651      ORDERED  Cleaning & Hygiene  KKPT280100
# 2      11264651      ORDERED       Flour & Sugar    KKFS0702
# 3      11264651      ORDERED    Salt & Seasoning    KKSS0002
# 4      11264651      ORDERED           Beverages    KKBE0105
# ...         ...          ...                 ...         ...
# 12237  10387712    COMPLETED       Flour & Sugar    KKFS0702
# 12238  10387712    COMPLETED         Meat & Fish    KKMF0100
# 12239  10387273    CANCELLED       Flour & Sugar    KKFS0222
# 12240  10387273    CANCELLED       Flour & Sugar    KKFSO172
# 12241  10387273    CANCELLED    Salt & Seasoning    KKSS1105
#
#        Customization Group  Customization Option  Quantity  Unit Price  \
# 0                      NaN                   NaN         1        4400
# 1                      NaN                   NaN         1         180
# ...

# %%
'''Nigeria Customers'''
n_cust=pd.read_csv("C:/Users/hp/Desktop/TOP UP MAMA ML/Nigeria Customers.csv")
n_cust
# Out:
#       Customer ID Last Used Platform  Is Blocked                Created At  \
# 0         3922702                WEB           0  2021-07-12T08:06:47.000Z
# 1         4058001                WEB           0  2021-08-05T08:22:35.000Z
# 2         4058334                WEB           0  2021-08-05T09:38:09.000Z
# 3         4058414                WEB           0  2021-08-05T09:56:57.000Z
# 4         4058431                WEB           0  2021-08-05T09:59:51.000Z
# ...           ...                ...         ...                       ...
# 1090      5161258                WEB           0  2022-02-11T07:11:38.000Z
# 1091      5166213                WEB           0  2022-02-12T08:45:47.000Z
# 1092      5176040                WEB           0  2022-02-14T11:23:01.000Z
# 1093      5184379                WEB           0  2022-02-16T09:59:58.000Z
# 1094      5186649                WEB           0  2022-02-16T21:37:04.000Z
#
# ...

# %%
'''Nigeria Deliveries'''
n_deliv=pd.read_csv("C:/Users/hp/Desktop/TOP UP MAMA ML/Nigeria Deliveries.csv")
n_deliv
# Out:
#         Task_ID       Order_ID  Relationship     Team_Name Task_Type Notes  \
# 0     368032956  YR-11262518,0  3.680330e+29  Default Team  Delivery   NaN
# 1     368032956  YR-11262518,0  3.680330e+29  Default Team  Delivery   NaN
# 2     368012178  YR-11261796,0  3.680122e+29  Default Team  Delivery   NaN
# 3     368012178  YR-11261796,0  3.680122e+29  Default Team  Delivery   NaN
# 4     367999205  YR-11261341,0  3.679992e+29  Default Team  Delivery   NaN
# ...         ...            ...           ...           ...       ...   ...
# 8014  299262559   YR-7740083,0  2.992626e+29  Default Team  Delivery   NaN
# 8015  299259587   YR-7739676,0  2.992596e+29  Default Team  Delivery   NaN
# 8016  299259586   YR-7739676,0  2.992596e+29  Default Team   Pick-up   NaN
# 8017  299251273   YR-7738989,0  2.992513e+29  Default Team  Delivery   NaN
# 8018  299251272   YR-7738989,0  2.992513e+29  Default Team   Pick-up   NaN
#
# ...

# %%
'''Nigeria Orders'''
n_orders=pd.read_csv("C:/Users/hp/Desktop/TOP UP MAMA ML/Nigeria Orders.csv")
n_orders
# Out:
#       Order ID Order Status  Category Name       SKU  Customization Group  \
# 0     11262518      ORDERED  Flour & Sugar  KNFS0001                  NaN
# 1     11262518      ORDERED        Spreads  KNSP2001                  NaN
# 2     11261796   DISPATCHED  Flour & Sugar  KNFS0001                  NaN
# 3     11261796   DISPATCHED        Spreads  KNSP2001                  NaN
# 4     11261341      ORDERED        Spreads  KNSP2001                  NaN
# ...        ...          ...            ...       ...                  ...
# 1424  10422797    COMPLETED      Beverages  KNBE0002                  NaN
# 1425  10422797    COMPLETED      Beverages  KNBE0001                  NaN
# 1426  10422634    COMPLETED  Flour & Sugar  KNFS0001                  NaN
# 1427  10422279    COMPLETED  Flour & Sugar  KNFS0001                  NaN
# 1428  10416692    COMPLETED  Flour & Sugar  KNFS0001                  NaN
#
#       Customization Option  Quantity  Unit Price  Cost Price  \
# ...

# %% [markdown]
# ## Task 2
# ### Data merging into one file

# %% [markdown]
# #### Merging the Kenya data

# %%
'''Checking the common Id to use for merging'''
k_cust.columns
# Out:
# Index(['Customer ID', 'Last Used Platform', 'Is Blocked', 'Created At',
#        'Language', 'Outstanding Amount', 'Loyalty Points',
#        'Number of employees', 'Upload restuarant location'],
#       dtype='object')

# %%
k_deliv.columns
# Out:
# Index(['Task_ID', 'Order_ID', 'Relationship', 'Team_Name', 'Task_Type',
#        'Notes', 'Agent_ID', 'Agent_Name', 'Distance(m)',
#        'Total_Time_Taken(min)', 'Pick_up_From', 'Start_Before',
#        'Complete_Before', 'Completion_Time', 'Task_Status', 'Ref_Images',
#        'Rating', 'Review', 'Latitude', 'Longitude', 'Tags', 'Promo_Applied',
#        'Custom_Template_ID', 'Task_Details_QTY', 'Task_Details_AMOUNT',
#        'Special_Instructions', 'Tip', 'Delivery_Charges', 'Discount',
#        'Subtotal', 'Payment_Type', 'Task_Category', 'Earning', 'Pricing',
#        'Unnamed: 34', 'Unnamed: 35'],
#       dtype='object')

# %%
k_orders.columns
# Out:
# Index(['Order ID', 'Order Status', 'Category Name', 'SKU',
#        'Customization Group', 'Customization Option', 'Quantity', 'Unit Price',
#        'Cost Price', 'Total Cost Price', 'Total Price', 'Order Total',
#        'Sub Total', 'Tax', 'Delivery Charge', 'Tip', 'Discount',
#        'Remaining Balance', 'Payment Method', 'Additional Charge',
#        'Taxable Amount', 'Transaction ID', 'Currency Symbol',
#        'Transaction Status', 'Promo Code', 'Customer ID', 'Merchant ID',
#        'Store Name', 'Pickup Address', 'Description', 'Distance (in km)',
#        'Order Time', 'Pickup Time', 'Delivery Time', 'Ratings', 'Reviews',
#        'Merchant Earning', 'Commission Amount', 'Commission Payout Status',
#        'Order Preparation Time', 'Debt Amount', 'Redeemed Loyalty Points',
#        'Consumed Loyalty Points', 'Cancellation Reason', 'Flat Discount',
#        'Checkout Template Name', 'Checkout Template Value'],
#       dtype='object')

# %%
n_cust.columns
# Out:
# Index(['Customer ID', 'Last Used Platform', 'Is Blocked', 'Created At',
#        'Language', 'Outstanding Amount', 'Loyalty Points',
#        'Number of Employees'],
#       dtype='object')

# %%
n_deliv.columns
# Out:
# Index(['Task_ID', 'Order_ID', 'Relationship', 'Team_Name', 'Task_Type',
#        'Notes', 'Agent_ID', 'Distance(m)', 'Total_Time_Taken(min)',
#        'Pick_up_From', 'Start_Before', 'Complete_Before', 'Completion_Time',
#        'Task_Status', 'Ref_Images', 'Rating', 'Review', 'Latitude',
#        'Longitude', 'Tags', 'Promo_Applied', 'Custom_Template_ID',
#        'Task_Details_QTY', 'Task_Details_AMOUNT', 'Special_Instructions',
#        'Tip', 'Delivery_Charges', 'Discount', 'Subtotal', 'Payment_Type',
#        'Task_Category', 'Earning', 'Pricing'],
#       dtype='object')

# %%
n_orders.columns
# Out:
# Index(['Order ID', 'Order Status', 'Category Name', 'SKU',
#        'Customization Group', 'Customization Option', 'Quantity', 'Unit Price',
#        'Cost Price', 'Total Cost Price', 'Total Price', 'Order Total',
#        'Sub Total', 'Tax', 'Delivery Charge', 'Tip', 'Discount',
#        'Remaining Balance', 'Payment Method', 'Additional Charge',
#        'Taxable Amount', 'Transaction ID', 'Currency Symbol',
#        'Transaction Status', 'Promo Code', 'Customer ID', 'Merchant ID',
#        'Store Name', 'Pickup Address', 'Description', 'Distance (in km)',
#        'Order Time', 'Pickup Time', 'Delivery Time', 'Ratings', 'Reviews',
#        'Merchant Earning', 'Commission Amount', 'Commission Payout Status',
#        'Order Preparation Time', 'Redeemed Loyalty Points',
#        'Consumed Loyalty Points', 'Cancellation Reason', 'Flat Discount',
#        'Checkout Template Name', 'Checkout Template Value'],
#       dtype='object')

# %%
'''Merging k_cut and k_orders'''
df1 = pd.merge(k_cust,k_orders, on="Customer ID")
df1
# Out:
#        Customer ID Last Used Platform  Is Blocked                Created At  \
# 0          3365019                WEB           0  2021-04-21T07:15:56.000Z
# 1          3365019                WEB           0  2021-04-21T07:15:56.000Z
# 2          3365019                WEB           0  2021-04-21T07:15:56.000Z
# 3          3365019                WEB           0  2021-04-21T07:15:56.000Z
# 4          3365770                WEB           0  2021-04-21T10:23:50.000Z
# ...            ...                ...         ...                       ...
# 12237      5188263                WEB           0  2022-02-17T09:51:36.000Z
# 12238      5188263                WEB           0  2022-02-17T09:51:36.000Z
# 12239      5188263                WEB           0  2022-02-17T09:51:36.000Z
# 12240      5188263                WEB           0  2022-02-17T09:51:36.000Z
# 12241      5189011                WEB           0  2022-02-17T13:07:11.000Z
#
# ...

# %%
'''Cleaning the order ID in k_deliv before merging'''
# k_deliv['Order_ID'] = k_deliv['Order_ID'].map(lambda x: x.lstrip('+-,').rstrip('aAbBcC'))
# Out:
# 'Cleaning the order ID in k_deliv before merging'

# %%
'''Removing the letters'''
k_deliv1=k_deliv.replace({'Order_ID':'[A-Za-z]'},'',regex=True)

# %%
k_deliv2=k_deliv1.replace({'Order_ID':'[-,]'},'',regex=True)

# %%
k_deliv2.head()
# Out:
#      Task_ID   Order_ID  Relationship     Team_Name Task_Type  \
# 0  368110390  112652160  3.681104e+29  Default Team  Delivery
# 1  368110390  112652160  3.681104e+29  Default Team  Delivery
# 2  368109621  112651750  3.681096e+29  Default Team  Delivery
# 3  368105817  112650150  3.681058e+29  Default Team  Delivery
# 4  368098308  112646510  3.680983e+29  Default Team  Delivery
#
#                                        Notes Agent_ID Agent_Name Distance(m)  \
# 0                                        NaN        -          -           -
# 1                                        NaN        -          -           -
# 2                                        NaN        -          -           -
# 3                                        NaN        -          -           -
# 4  Urgently deliver by 9.30am in the morning        -          -           -
#
#   Total_Time_Taken(min)  ...       Tip Delivery_Charges    Discount Subtotal  \
# ...

# %%
df1.head()
# Out:
#    Customer ID Last Used Platform  Is Blocked                Created At  \
# 0      3365019                WEB           0  2021-04-21T07:15:56.000Z
# 1      3365019                WEB           0  2021-04-21T07:15:56.000Z
# 2      3365019                WEB           0  2021-04-21T07:15:56.000Z
# 3      3365019                WEB           0  2021-04-21T07:15:56.000Z
# 4      3365770                WEB           0  2021-04-21T10:23:50.000Z
#
#   Language  Outstanding Amount  Loyalty Points  Number of employees  \
# 0       en                   0              68                  NaN
# 1       en                   0              68                  NaN
# 2       en                   0              68                  NaN
# 3       en                   0              68                  NaN
# 4       en                   0              55                  NaN
#
#   Upload restuarant location  Order ID  ... Commission Amount  \
# ...

# %%
df1.columns
# Out:
# Index(['Customer ID', 'Last Used Platform', 'Is Blocked', 'Created At',
#        'Language', 'Outstanding Amount', 'Loyalty Points',
#        'Number of employees', 'Upload restuarant location', 'Order ID',
#        'Order Status', 'Category Name', 'SKU', 'Customization Group',
#        'Customization Option', 'Quantity', 'Unit Price', 'Cost Price',
#        'Total Cost Price', 'Total Price', 'Order Total', 'Sub Total', 'Tax',
#        'Delivery Charge', 'Tip', 'Discount', 'Remaining Balance',
#        'Payment Method', 'Additional Charge', 'Taxable Amount',
#        'Transaction ID', 'Currency Symbol', 'Transaction Status', 'Promo Code',
#        'Merchant ID', 'Store Name', 'Pickup Address', 'Description',
#        'Distance (in km)', 'Order Time', 'Pickup Time', 'Delivery Time',
#        'Ratings', 'Reviews', 'Merchant Earning', 'Commission Amount',
#        'Commission Payout Status', 'Order Preparation Time', 'Debt Amount',
# ...

# %%
'''Renaming the Order_ID column in k_deliv2 to order ID'''
k_deliv2.rename(columns={"Order_ID":"Order ID",},inplace=True)

# %%
k_deliv2.head()
# Out:
#      Task_ID   Order ID  Relationship     Team_Name Task_Type  \
# 0  368110390  112652160  3.681104e+29  Default Team  Delivery
# 1  368110390  112652160  3.681104e+29  Default Team  Delivery
# 2  368109621  112651750  3.681096e+29  Default Team  Delivery
# 3  368105817  112650150  3.681058e+29  Default Team  Delivery
# 4  368098308  112646510  3.680983e+29  Default Team  Delivery
#
#                                        Notes Agent_ID Agent_Name Distance(m)  \
# 0                                        NaN        -          -           -
# 1                                        NaN        -          -           -
# 2                                        NaN        -          -           -
# 3                                        NaN        -          -           -
# 4  Urgently deliver by 9.30am in the morning        -          -           -
#
#   Total_Time_Taken(min)  ...       Tip Delivery_Charges    Discount Subtotal  \
# ...

# %%
datatypes = df1.dtypes['Order ID']
datatypes
# Out:
# dtype('int64')

# %%
datatypes = k_deliv2.dtypes['Order ID']
datatypes
# Out:
# dtype('O')

# %%
# k_deliv2["Order ID"].astype(np.int64)
# k_deliv2["Order ID"].astype(int(float('')))

# %%
# '''Merge df1 with k_deliv2'''
# df2=pd.merge(df1, k_deliv2, on="Order ID", how="outer")

# %%
df1=df1.set_index("Order ID")

# %%
df1.head()
# Out:
#           Customer ID Last Used Platform  Is Blocked  \
# Order ID
# 11155410      3365019                WEB           0
# 11155410      3365019                WEB           0
# 11155410      3365019                WEB           0
# 11138864      3365019                WEB           0
# 11253217      3365770                WEB           0
#
#                         Created At Language  Outstanding Amount  \
# Order ID
# 11155410  2021-04-21T07:15:56.000Z       en                   0
# 11155410  2021-04-21T07:15:56.000Z       en                   0
# 11155410  2021-04-21T07:15:56.000Z       en                   0
# 11138864  2021-04-21T07:15:56.000Z       en                   0
# 11253217  2021-04-21T10:23:50.000Z       en                   0
#
#           Loyalty Points  Number of employees Upload restuarant location  \
# Order ID
# 11155410              68                  NaN                        NaN
# 11155410              68                  NaN                        NaN
# ...

# %%
k_deliv2=k_deliv2.set_index("Order ID")
k_deliv2.head()
# Out:
#              Task_ID  Relationship     Team_Name Task_Type  \
# Order ID
# 112652160  368110390  3.681104e+29  Default Team  Delivery
# 112652160  368110390  3.681104e+29  Default Team  Delivery
# 112651750  368109621  3.681096e+29  Default Team  Delivery
# 112650150  368105817  3.681058e+29  Default Team  Delivery
# 112646510  368098308  3.680983e+29  Default Team  Delivery
#
#                                                Notes Agent_ID Agent_Name  \
# Order ID
# 112652160                                        NaN        -          -
# 112652160                                        NaN        -          -
# 112651750                                        NaN        -          -
# 112650150                                        NaN        -          -
# 112646510  Urgently deliver by 9.30am in the morning        -          -
#
#           Distance(m) Total_Time_Taken(min) Pick_up_From  ...       Tip  \
# Order ID                                                  ...
# ...

# %%
df2=pd.concat([df1, k_deliv2])
df2
# Out:
#           Customer ID Last Used Platform  Is Blocked  \
# Order ID
# 11155410    3365019.0                WEB         0.0
# 11155410    3365019.0                WEB         0.0
# 11155410    3365019.0                WEB         0.0
# 11138864    3365019.0                WEB         0.0
# 11253217    3365770.0                WEB         0.0
# ...               ...                ...         ...
# 53196660          NaN                NaN         NaN
# 53048300          NaN                NaN         NaN
# 53046900          NaN                NaN         NaN
# 53046900          NaN                NaN         NaN
# 53046900          NaN                NaN         NaN
#
#                         Created At Language  Outstanding Amount  \
# Order ID
# 11155410  2021-04-21T07:15:56.000Z       en                 0.0
# 11155410  2021-04-21T07:15:56.000Z       en                 0.0
# 11155410  2021-04-21T07:15:56.000Z       en                 0.0
# ...

# %%
kenya_data=df2
kenya_data.head()
# Out:
#           Customer ID Last Used Platform  Is Blocked  \
# Order ID
# 11155410    3365019.0                WEB         0.0
# 11155410    3365019.0                WEB         0.0
# 11155410    3365019.0                WEB         0.0
# 11138864    3365019.0                WEB         0.0
# 11253217    3365770.0                WEB         0.0
#
#                         Created At Language  Outstanding Amount  \
# Order ID
# 11155410  2021-04-21T07:15:56.000Z       en                 0.0
# 11155410  2021-04-21T07:15:56.000Z       en                 0.0
# 11155410  2021-04-21T07:15:56.000Z       en                 0.0
# 11138864  2021-04-21T07:15:56.000Z       en                 0.0
# 11253217  2021-04-21T10:23:50.000Z       en                 0.0
#
#           Loyalty Points  Number of employees Upload restuarant location  \
# Order ID
# 11155410            68.0                  NaN                        NaN
# 11155410            68.0                  NaN                        NaN
# ...

# %% [markdown]
# #### Merging the Nigeria data

# %%
n_cust.columns
# Out:
# Index(['Customer ID', 'Last Used Platform', 'Is Blocked', 'Created At',
#        'Language', 'Outstanding Amount', 'Loyalty Points',
#        'Number of Employees'],
#       dtype='object')

# %%
n_deliv.columns
# Out:
# Index(['Task_ID', 'Order_ID', 'Relationship', 'Team_Name', 'Task_Type',
#        'Notes', 'Agent_ID', 'Distance(m)', 'Total_Time_Taken(min)',
#        'Pick_up_From', 'Start_Before', 'Complete_Before', 'Completion_Time',
#        'Task_Status', 'Ref_Images', 'Rating', 'Review', 'Latitude',
#        'Longitude', 'Tags', 'Promo_Applied', 'Custom_Template_ID',
#        'Task_Details_QTY', 'Task_Details_AMOUNT', 'Special_Instructions',
#        'Tip', 'Delivery_Charges', 'Discount', 'Subtotal', 'Payment_Type',
#        'Task_Category', 'Earning', 'Pricing'],
#       dtype='object')

# %%
n_orders.columns
# Out:
# Index(['Order ID', 'Order Status', 'Category Name', 'SKU',
#        'Customization Group', 'Customization Option', 'Quantity', 'Unit Price',
#        'Cost Price', 'Total Cost Price', 'Total Price', 'Order Total',
#        'Sub Total', 'Tax', 'Delivery Charge', 'Tip', 'Discount',
#        'Remaining Balance', 'Payment Method', 'Additional Charge',
#        'Taxable Amount', 'Transaction ID', 'Currency Symbol',
#        'Transaction Status', 'Promo Code', 'Customer ID', 'Merchant ID',
#        'Store Name', 'Pickup Address', 'Description', 'Distance (in km)',
#        'Order Time', 'Pickup Time', 'Delivery Time', 'Ratings', 'Reviews',
#        'Merchant Earning', 'Commission Amount', 'Commission Payout Status',
#        'Order Preparation Time', 'Redeemed Loyalty Points',
#        'Consumed Loyalty Points', 'Cancellation Reason', 'Flat Discount',
#        'Checkout Template Name', 'Checkout Template Value'],
#       dtype='object')

# %%
df3=pd.merge(n_cust,n_orders, on="Customer ID")
df3.head()
# Out:
#    Customer ID Last Used Platform  Is Blocked                Created At  \
# 0      4069636                WEB           0  2021-08-07T12:08:27.000Z
# 1      4069636                WEB           0  2021-08-07T12:08:27.000Z
# 2      4069636                WEB           0  2021-08-07T12:08:27.000Z
# 3      4069636                WEB           0  2021-08-07T12:08:27.000Z
# 4      4069636                WEB           0  2021-08-07T12:08:27.000Z
#
#   Language  Outstanding Amount  Loyalty Points  Number of Employees  Order ID  \
# 0       en                   0            1235                  4.0  11167514
# 1       en                   0            1235                  4.0  11095740
# 2       en                   0            1235                  4.0  11001517
# 3       en                   0            1235                  4.0  10718478
# 4       en                   0            1235                  4.0  10622259
#
#   Order Status  ... Merchant Earning Commission Amount  \
# ...

# %%
n_deliv.head()
# Out:
#      Task_ID       Order_ID  Relationship     Team_Name Task_Type Notes  \
# 0  368032956  YR-11262518,0  3.680330e+29  Default Team  Delivery   NaN
# 1  368032956  YR-11262518,0  3.680330e+29  Default Team  Delivery   NaN
# 2  368012178  YR-11261796,0  3.680122e+29  Default Team  Delivery   NaN
# 3  368012178  YR-11261796,0  3.680122e+29  Default Team  Delivery   NaN
# 4  367999205  YR-11261341,0  3.679992e+29  Default Team  Delivery   NaN
#
#   Agent_ID Distance(m) Total_Time_Taken(min) Pick_up_From  ...  \
# 0  1150142           -                     -   Topup Mama  ...
# 1  1150142           -                     -   Topup Mama  ...
# 2  1166840          11                     -   Topup Mama  ...
# 3  1166840          11                     -   Topup Mama  ...
# 4  1233220           -                     -   Topup Mama  ...
#
#   Task_Details_AMOUNT Special_Instructions     Tip Delivery_Charges Discount  \
# ...

# %%
'''Cleaning the Order_ID column'''
n_deliv1=n_deliv.replace({'Order_ID':'[A-Za-z]'},'',regex=True)
# k_deliv1=k_deliv.replace({'Order_ID':'[A-Za-z]'},'',regex=True)
n_deliv1.head()
# Out:
#      Task_ID     Order_ID  Relationship     Team_Name Task_Type Notes  \
# 0  368032956  -11262518,0  3.680330e+29  Default Team  Delivery   NaN
# 1  368032956  -11262518,0  3.680330e+29  Default Team  Delivery   NaN
# 2  368012178  -11261796,0  3.680122e+29  Default Team  Delivery   NaN
# 3  368012178  -11261796,0  3.680122e+29  Default Team  Delivery   NaN
# 4  367999205  -11261341,0  3.679992e+29  Default Team  Delivery   NaN
#
#   Agent_ID Distance(m) Total_Time_Taken(min) Pick_up_From  ...  \
# 0  1150142           -                     -   Topup Mama  ...
# 1  1150142           -                     -   Topup Mama  ...
# 2  1166840          11                     -   Topup Mama  ...
# 3  1166840          11                     -   Topup Mama  ...
# 4  1233220           -                     -   Topup Mama  ...
#
#   Task_Details_AMOUNT Special_Instructions     Tip Delivery_Charges Discount  \
# 0         ₦ 104250.00                    -       -                -        -
# ...

# %%
n_deliv2=n_deliv1.replace({'Order_ID':'[-,]'},'',regex=True)
n_deliv2
# Out:
#         Task_ID   Order_ID  Relationship     Team_Name Task_Type Notes  \
# 0     368032956  112625180  3.680330e+29  Default Team  Delivery   NaN
# 1     368032956  112625180  3.680330e+29  Default Team  Delivery   NaN
# 2     368012178  112617960  3.680122e+29  Default Team  Delivery   NaN
# 3     368012178  112617960  3.680122e+29  Default Team  Delivery   NaN
# 4     367999205  112613410  3.679992e+29  Default Team  Delivery   NaN
# ...         ...        ...           ...           ...       ...   ...
# 8014  299262559   77400830  2.992626e+29  Default Team  Delivery   NaN
# 8015  299259587   77396760  2.992596e+29  Default Team  Delivery   NaN
# 8016  299259586   77396760  2.992596e+29  Default Team   Pick-up   NaN
# 8017  299251273   77389890  2.992513e+29  Default Team  Delivery   NaN
# 8018  299251272   77389890  2.992513e+29  Default Team   Pick-up   NaN
#
#      Agent_ID Distance(m) Total_Time_Taken(min)           Pick_up_From  ...  \
# ...

# %%
'''Renaming the Order_ID column in n_deliv2 to order ID'''
n_deliv2.rename(columns={"Order_ID":"Order ID",},inplace=True)

# %%
n_deliv2=n_deliv2.set_index('Order ID')
n_deliv2.head()
# Out:
#              Task_ID  Relationship     Team_Name Task_Type Notes Agent_ID  \
# Order ID
# 112625180  368032956  3.680330e+29  Default Team  Delivery   NaN  1150142
# 112625180  368032956  3.680330e+29  Default Team  Delivery   NaN  1150142
# 112617960  368012178  3.680122e+29  Default Team  Delivery   NaN  1166840
# 112617960  368012178  3.680122e+29  Default Team  Delivery   NaN  1166840
# 112613410  367999205  3.679992e+29  Default Team  Delivery   NaN  1233220
#
#           Distance(m) Total_Time_Taken(min) Pick_up_From  \
# Order ID
# 112625180           -                     -   Topup Mama
# 112625180           -                     -   Topup Mama
# 112617960          11                     -   Topup Mama
# 112617960          11                     -   Topup Mama
# 112613410           -                     -   Topup Mama
#
#                       Start_Before  ... Task_Details_AMOUNT  \
# Order ID                            ...
# ...

# %%
'''setting order as index in df3'''
df3=df3.set_index('Order ID')
df3.head()
# Out:
#           Customer ID Last Used Platform  Is Blocked  \
# Order ID
# 11167514      4069636                WEB           0
# 11095740      4069636                WEB           0
# 11001517      4069636                WEB           0
# 10718478      4069636                WEB           0
# 10622259      4069636                WEB           0
#
#                         Created At Language  Outstanding Amount  \
# Order ID
# 11167514  2021-08-07T12:08:27.000Z       en                   0
# 11095740  2021-08-07T12:08:27.000Z       en                   0
# 11001517  2021-08-07T12:08:27.000Z       en                   0
# 10718478  2021-08-07T12:08:27.000Z       en                   0
# 10622259  2021-08-07T12:08:27.000Z       en                   0
#
#           Loyalty Points  Number of Employees Order Status  Category Name  \
# Order ID
# 11167514            1235                  4.0    COMPLETED  Flour & Sugar
# 11095740            1235                  4.0    COMPLETED  Flour & Sugar
# ...

# %%
'''Concatinating'''
nigeria_data=pd.concat([df3, n_deliv2])
nigeria_data.head()
# Out:
#           Customer ID Last Used Platform  Is Blocked  \
# Order ID
# 11167514    4069636.0                WEB         0.0
# 11095740    4069636.0                WEB         0.0
# 11001517    4069636.0                WEB         0.0
# 10718478    4069636.0                WEB         0.0
# 10622259    4069636.0                WEB         0.0
#
#                         Created At Language  Outstanding Amount  \
# Order ID
# 11167514  2021-08-07T12:08:27.000Z       en                 0.0
# 11095740  2021-08-07T12:08:27.000Z       en                 0.0
# 11001517  2021-08-07T12:08:27.000Z       en                 0.0
# 10718478  2021-08-07T12:08:27.000Z       en                 0.0
# 10622259  2021-08-07T12:08:27.000Z       en                 0.0
#
#           Loyalty Points  Number of Employees Order Status  Category Name  \
# Order ID
# 11167514          1235.0                  4.0    COMPLETED  Flour & Sugar
# 11095740          1235.0                  4.0    COMPLETED  Flour & Sugar
# ...

# %%
### Merging kenya data and nigeria data into one file
data=pd.concat([kenya_data,nigeria_data])
data.head()
# Out:
#           Customer ID Last Used Platform  Is Blocked  \
# Order ID
# 11155410    3365019.0                WEB         0.0
# 11155410    3365019.0                WEB         0.0
# 11155410    3365019.0                WEB         0.0
# 11138864    3365019.0                WEB         0.0
# 11253217    3365770.0                WEB         0.0
#
#                         Created At Language  Outstanding Amount  \
# Order ID
# 11155410  2021-04-21T07:15:56.000Z       en                 0.0
# 11155410  2021-04-21T07:15:56.000Z       en                 0.0
# 11155410  2021-04-21T07:15:56.000Z       en                 0.0
# 11138864  2021-04-21T07:15:56.000Z       en                 0.0
# 11253217  2021-04-21T10:23:50.000Z       en                 0.0
#
#           Loyalty Points  Number of employees Upload restuarant location  \
# Order ID
# 11155410            68.0                  NaN                        NaN
# 11155410            68.0                  NaN                        NaN
# ...

# %%
data.columns
# Out:
# Index(['Customer ID', 'Last Used Platform', 'Is Blocked', 'Created At',
#        'Language', 'Outstanding Amount', 'Loyalty Points',
#        'Number of employees', 'Upload restuarant location', 'Order Status',
#        'Category Name', 'SKU', 'Customization Group', 'Customization Option',
#        'Quantity', 'Unit Price', 'Cost Price', 'Total Cost Price',
#        'Total Price', 'Order Total', 'Sub Total', 'Tax', 'Delivery Charge',
#        'Tip', 'Discount', 'Remaining Balance', 'Payment Method',
#        'Additional Charge', 'Taxable Amount', 'Transaction ID',
#        'Currency Symbol', 'Transaction Status', 'Promo Code', 'Merchant ID',
#        'Store Name', 'Pickup Address', 'Description', 'Distance (in km)',
#        'Order Time', 'Pickup Time', 'Delivery Time', 'Ratings', 'Reviews',
#        'Merchant Earning', 'Commission Amount', 'Commission Payout Status',
#        'Order Preparation Time', 'Debt Amount', 'Redeemed Loyalty Points',
# ...

# %% [markdown]
# ### EDA

# %%
'''Summary statistics'''
data.describe()
# Out:
#         Customer ID  Is Blocked  Outstanding Amount  Loyalty Points  \
# count  1.367100e+04     13671.0             13671.0    13671.000000
# mean   4.313161e+06         0.0                 0.0      787.236486
# std    3.756198e+05         0.0                 0.0     1343.196071
# min    3.365019e+06         0.0                 0.0        0.000000
# 25%    4.052828e+06         0.0                 0.0      115.000000
# 50%    4.276916e+06         0.0                 0.0      309.000000
# 75%    4.594878e+06         0.0                 0.0      893.000000
# max    5.189011e+06         0.0                 0.0    23307.000000
#
#        Number of employees  Customization Group  Customization Option  \
# count          8667.000000                  0.0                   0.0
# mean              5.871351                  NaN                   NaN
# std               8.004597                  NaN                   NaN
# min               1.000000                  NaN                   NaN
# ...

# %%
'''length'''
len(data)
# Out:
# 66673

# %%
data=data.reset_index()
data.head()
# Out:
#    Order ID  Customer ID Last Used Platform  Is Blocked  \
# 0  11155410    3365019.0                WEB         0.0
# 1  11155410    3365019.0                WEB         0.0
# 2  11155410    3365019.0                WEB         0.0
# 3  11138864    3365019.0                WEB         0.0
# 4  11253217    3365770.0                WEB         0.0
#
#                  Created At Language  Outstanding Amount  Loyalty Points  \
# 0  2021-04-21T07:15:56.000Z       en                 0.0            68.0
# 1  2021-04-21T07:15:56.000Z       en                 0.0            68.0
# 2  2021-04-21T07:15:56.000Z       en                 0.0            68.0
# 3  2021-04-21T07:15:56.000Z       en                 0.0            68.0
# 4  2021-04-21T10:23:50.000Z       en                 0.0            55.0
#
#    Number of employees Upload restuarant location  ... Special_Instructions  \
# 0                  NaN                        NaN  ...                  NaN
# ...

# %%
'''Checking null values'''
data.isna().sum()
# Out:
# Order ID                   0
# Customer ID            53002
# Last Used Platform     53002
# Is Blocked             53002
# Created At             53002
#                        ...
# Earning                13671
# Pricing                13671
# Unnamed: 34            66564
# Unnamed: 35            66634
# Number of Employees    65723
# Length: 89, dtype: int64

# %%
# checking the value counts of each data type 
display(data.dtypes.value_counts())
# Out:
# object     60
# float64    29
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66673 entries, 0 to 66672
# Data columns (total 89 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Order ID                    66673 non-null  object
#  1   Customer ID                 13671 non-null  float64
#  2   Last Used Platform          13671 non-null  object
#  3   Is Blocked                  13671 non-null  float64
#  4   Created At                  13671 non-null  object
#  5   Language                    13671 non-null  object
#  6   Outstanding Amount          13671 non-null  float64
#  7   Loyalty Points              13671 non-null  float64
#  8   Number of employees         8667 non-null   float64
#  9   Upload restuarant location  6 non-null      object
#  10  Order Status                13671 non-null  object
#  11  Category Name               13665 non-null  object
#  12  SKU                         13668 non-null  object
# ...
